# %% [markdown]
# # Clustering metrics - alternatives to the _elbow method_
# ### Dr. Tirthajyoti Sarkar, Fremont, CA 94536
#
# Clustering is an important part of the machine learning pipeline for business or scientific enterprises utilizing data science. As the name suggests, it helps to identify congregations of closely related (by some measure of distance) data points in a blob of data, which, otherwise, would be difficult to make sense of.
#
# A popular method like k-means clustering does not seem to provide a completely satisfactory answer when we ask the basic question:
# > **"How would we know the actual number of clusters, to begin with?"**
#
# This question is critically important because of the fact that the process of clustering is often a precursor to further processing of the individual cluster data and therefore, the amount of computational resource may depend on this measurement.
#
# In the case of a business analytics problem, repercussion could be worse. Clustering is often done for such analytics with the goal of market segmentation. It is, therefore, easily conceivable that, depending on the number of clusters, appropriate marketing personnel will be allocated to the problem. Consequently, a wrong assessment of the number of clusters can lead to sub-optimum allocation of precious resources.
#
# For the k-means clustering method, the most common approach for answering this question is the so-called elbow method. It involves running the algorithm multiple times over a loop, with an increasing number of cluster choice and then plotting a clustering score as a function of the number of clusters.
#
# In this notebook, we show what metric to use for visualizing and determining an optimal number of clusters much better than the usual practice - elbow method.
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Create synthetic data using Scikit learn `make_blob` method
#
# - Number of features: 4
# - Number of clusters: 5
# - Number of samples: 200

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %%
n_features = 4
n_cluster = 5
cluster_std = 1.2
n_samples = 200

# %%
data1 = make_blobs(n_samples=n_samples,n_features=n_features,centers=n_cluster,cluster_std=cluster_std)

# %%
d1 = data1[0]

# %%
print()

# %%
df1=pd.DataFrame(data=d1,columns=['Feature_'+str(i) for i in range(1,n_features+1)])
df1.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4
# 0  -3.702128  -8.739545  -4.458566   2.120062
# 1  -0.993699   3.186988   2.004364 -10.092982
# 2  -3.875939   4.892325  -7.904399  -5.105024
# 3  -4.717608   2.852345  -9.240319  -5.291090
# 4  -7.224028  11.277698   8.429913   1.825318

# %%
from itertools import combinations

# %%
lst_vars=list(combinations(df1.columns,2))

# %%
len(lst_vars)
# Out:
# 6

# %%
plt.figure(figsize=(15,8))
for i in range(1,7):
    plt.subplot(2,3,i)
    dim1=lst_vars[i-1][0]
    dim2=lst_vars[i-1][1]
    plt.scatter(df1[dim1],df1[dim2],c=data1[1],edgecolor='k',s=150)
    plt.xlabel(f"{dim1}",fontsize=13)
    plt.ylabel(f"{dim2}",fontsize=13)

# %% [markdown]
# ### How are the classes separated (boxplots)

# %%
plt.figure(figsize=(16,14))
for i,c in enumerate(df1.columns):
    plt.subplot(3,2,i+1)
    sns.boxplot(y=df1[c],x=data1[1])
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel("Class",fontsize=15)
    plt.ylabel(c,fontsize=15)
    #plt.show()

# %% [markdown]
# ## k-means clustering

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Unlabled data

# %%
df1=pd.read_csv("/home/aditya/data-science-project/Data/winequality-red.csv")
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X=df1

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
y=data1[1]

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score,v_measure_score

# %% [markdown]
# ### Running k-means and computing inter-cluster distance score for various *k* values

# %%
km_scores= []
km_silhouette = []
vmeasure_score =[]
db_score = []
for i in range(2,12):
    km = KMeans(n_clusters=i, random_state=0).fit(X_scaled)
    preds = km.predict(X_scaled)
    
    print("Score for number of cluster(s) {}: {}".format(i,km.score(X_scaled)))
    km_scores.append(-km.score(X_scaled))
    
    silhouette = silhouette_score(X_scaled,preds)
    km_silhouette.append(silhouette)
    print("Silhouette score for number of cluster(s) {}: {}".format(i,silhouette))
    
    db = davies_bouldin_score(X_scaled,preds)
    db_score.append(db)
    print("Davies Bouldin score for number of cluster(s) {}: {}".format(i,db))
    
    #v_measure = v_measure_score(y,preds)
    vmeasure_score.append(v_measure)
    print("V-measure score for number of cluster(s) {}: {}".format(i,v_measure))
    print("-"*100)
# Out:
# Score for number of cluster(s) 2: -276.91361644012534
# Silhouette score for number of cluster(s) 2: 0.23407882190437648
# Davies Bouldin score for number of cluster(s) 2: 1.7024491902978094
# V-measure score for number of cluster(s) 2: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 3: -241.19699842623507
# Silhouette score for number of cluster(s) 3: 0.2063216944325484
# Davies Bouldin score for number of cluster(s) 3: 1.5906762052277805
# V-measure score for number of cluster(s) 3: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 4: -215.69027737832505
# Silhouette score for number of cluster(s) 4: 0.1886571183302695
# Davies Bouldin score for number of cluster(s) 4: 1.6184657585245614
# V-measure score for number of cluster(s) 4: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 5: -197.5896202492431
# Silhouette score for number of cluster(s) 5: 0.18064314743002394
# Davies Bouldin score for number of cluster(s) 5: 1.6353913951883776
# V-measure score for number of cluster(s) 5: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 6: -186.5705081392137
# Silhouette score for number of cluster(s) 6: 0.18886406381826878
# Davies Bouldin score for number of cluster(s) 6: 1.5131013249537588
# V-measure score for number of cluster(s) 6: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 7: -178.4474132190645
# Silhouette score for number of cluster(s) 7: 0.163708671900467
# Davies Bouldin score for number of cluster(s) 7: 1.552139301094996
# V-measure score for number of cluster(s) 7: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 8: -170.5124011397246
# Silhouette score for number of cluster(s) 8: 0.14341406676607688
# Davies Bouldin score for number of cluster(s) 8: 1.6045455267020994
# V-measure score for number of cluster(s) 8: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 9: -164.66684162329727
# Silhouette score for number of cluster(s) 9: 0.13496810947661764
# Davies Bouldin score for number of cluster(s) 9: 1.711732632840503
# V-measure score for number of cluster(s) 9: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 10: -157.9796775484845
# Silhouette score for number of cluster(s) 10: 0.14885664276401128
# Davies Bouldin score for number of cluster(s) 10: 1.6381373591784325
# V-measure score for number of cluster(s) 10: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 11: -153.55667477233197
# Silhouette score for number of cluster(s) 11: 0.14401182074334645
# Davies Bouldin score for number of cluster(s) 11: 1.7164760196068913
# V-measure score for number of cluster(s) 11: 0.7966681821413034
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The elbow method for determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_scores,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("K-means score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=vmeasure_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("V-measure score")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("The silhouette coefficient method \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_silhouette,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Silhouette score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=db_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Davies-Bouldin score")
plt.show()

# %% [markdown]
# ## Expectation-maximization (Gaussian Mixture Model)

# %%
from sklearn.mixture import GaussianMixture

# %%
gm_bic= []
gm_score=[]
for i in range(2,12):
    gm = GaussianMixture(n_components=i,n_init=10,tol=1e-3,max_iter=1000).fit(X_scaled)
    print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(X_scaled)))
    print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(X_scaled)))
    print("-"*100)
    gm_bic.append(-gm.bic(X_scaled))
    gm_score.append(gm.score(X_scaled))
# Out:
# BIC for number of cluster(s) 2: -757.5247821388707
# Log-likelihood score for number of cluster(s) 2: 2.2779399644219094
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: -886.8407845764807
# Log-likelihood score for number of cluster(s) 3: 2.7999168717614857
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: -1048.7834209720065
# Log-likelihood score for number of cluster(s) 4: 3.4034603639958516
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: -1073.0632999307622
# Log-likelihood score for number of cluster(s) 5: 3.6628469626382922
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: -1041.8578109391815
# Log-likelihood score for number of cluster(s) 6: 3.783520141404892
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: -975.4379157004206
# Log-likelihood score for number of cluster(s) 7: 3.8161573045535406
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: -913.8683739960064
# Log-likelihood score for number of cluster(s) 8: 3.860920351538057
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: -869.586610230686
# Log-likelihood score for number of cluster(s) 9: 3.9489028433703073
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: -830.0852612776088
# Log-likelihood score for number of cluster(s) 10: 4.048836372233166
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: -796.0129993322091
# Log-likelihood score for number of cluster(s) 11: 4.1623426186152175
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The Gaussian Mixture model BIC \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=np.log(gm_bic),s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Log of Gaussian mixture BIC score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=gm_score,s=150,edgecolor='k')
plt.show()
