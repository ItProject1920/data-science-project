# %% [markdown]
# # Clustering metrics - alternatives to the _elbow method_
# ### Dr. Tirthajyoti Sarkar, Fremont, CA 94536
#
# Clustering is an important part of the machine learning pipeline for business or scientific enterprises utilizing data science. As the name suggests, it helps to identify congregations of closely related (by some measure of distance) data points in a blob of data, which, otherwise, would be difficult to make sense of.
#
# A popular method like k-means clustering does not seem to provide a completely satisfactory answer when we ask the basic question:
# > **"How would we know the actual number of clusters, to begin with?"**
#
# This question is critically important because of the fact that the process of clustering is often a precursor to further processing of the individual cluster data and therefore, the amount of computational resource may depend on this measurement.
#
# In the case of a business analytics problem, repercussion could be worse. Clustering is often done for such analytics with the goal of market segmentation. It is, therefore, easily conceivable that, depending on the number of clusters, appropriate marketing personnel will be allocated to the problem. Consequently, a wrong assessment of the number of clusters can lead to sub-optimum allocation of precious resources.
#
# For the k-means clustering method, the most common approach for answering this question is the so-called elbow method. It involves running the algorithm multiple times over a loop, with an increasing number of cluster choice and then plotting a clustering score as a function of the number of clusters.
#
# In this notebook, we show what metric to use for visualizing and determining an optimal number of clusters much better than the usual practice - elbow method.
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Create synthetic data using Scikit learn `make_blob` method
#
# - Number of features: 4
# - Number of clusters: 5
# - Number of samples: 200

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %%
n_features = 4
n_cluster = 5
cluster_std = 1.2
n_samples = 200

# %%
data1 = make_blobs(n_samples=n_samples,n_features=n_features,centers=n_cluster,cluster_std=cluster_std)

# %%
d1 = data1[0]

# %%
df1=pd.DataFrame(data=d1,columns=['Feature_'+str(i) for i in range(1,n_features+1)])
df1.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4
# 0  -7.526240   4.818715  11.228650  -7.899300
# 1   5.422437  -7.770909  -9.871829   1.781707
# 2   3.179068   2.430630  -4.659603   2.548935
# 3  -5.105818   5.519220   9.780712  -9.503564
# 4   5.848120  -3.245720  -6.875729   1.604635

# %%
from itertools import combinations

# %%
lst_vars=list(combinations(df1.columns,2))

# %%
len(lst_vars)
# Out:
# 6

# %%
plt.figure(figsize=(15,8))
for i in range(1,7):
    plt.subplot(2,3,i)
    dim1=lst_vars[i-1][0]
    dim2=lst_vars[i-1][1]
    plt.scatter(df1[dim1],df1[dim2],c=data1[1],edgecolor='k',s=150)
    plt.xlabel(f"{dim1}",fontsize=13)
    plt.ylabel(f"{dim2}",fontsize=13)

# %% [markdown]
# ### How are the classes separated (boxplots)

# %%
plt.figure(figsize=(16,14))
for i,c in enumerate(df1.columns):
    plt.subplot(3,2,i+1)
    sns.boxplot(y=df1[c],x=data1[1])
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel("Class",fontsize=15)
    plt.ylabel(c,fontsize=15)
    #plt.show()

# %% [markdown]
# ## k-means clustering

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Unlabled data

# %%
X=df1

# %%
X.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4
# 0  -7.526240   4.818715  11.228650  -7.899300
# 1   5.422437  -7.770909  -9.871829   1.781707
# 2   3.179068   2.430630  -4.659603   2.548935
# 3  -5.105818   5.519220   9.780712  -9.503564
# 4   5.848120  -3.245720  -6.875729   1.604635

# %%
y=data1[1]

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score,v_measure_score

# %% [markdown]
# ### Running k-means and computing inter-cluster distance score for various *k* values

# %%
km_scores= []
km_silhouette = []
vmeasure_score =[]
db_score = []
for i in range(2,12):
    km = KMeans(n_clusters=i, random_state=0).fit(X_scaled)
    preds = km.predict(X_scaled)
    
    print("Score for number of cluster(s) {}: {}".format(i,km.score(X_scaled)))
    km_scores.append(-km.score(X_scaled))
    
    silhouette = silhouette_score(X_scaled,preds)
    km_silhouette.append(silhouette)
    print("Silhouette score for number of cluster(s) {}: {}".format(i,silhouette))
    
    db = davies_bouldin_score(X_scaled,preds)
    db_score.append(db)
    print("Davies Bouldin score for number of cluster(s) {}: {}".format(i,db))
    
    v_measure = v_measure_score(y,preds)
    vmeasure_score.append(v_measure)
    print("V-measure score for number of cluster(s) {}: {}".format(i,v_measure))
    print("-"*100)
# Out:
# Score for number of cluster(s) 2: -14.383269287313318
# Silhouette score for number of cluster(s) 2: 0.7179245138387627
# Davies Bouldin score for number of cluster(s) 2: 0.32355972618747114
# V-measure score for number of cluster(s) 2: 0.47435098761403227
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 3: -8.136479927966793
# Silhouette score for number of cluster(s) 3: 0.4852004962587469
# Davies Bouldin score for number of cluster(s) 3: 0.743616083754716
# V-measure score for number of cluster(s) 3: 0.6638795999256721
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 4: -4.364139359267124
# Silhouette score for number of cluster(s) 4: 0.5744939380114374
# Davies Bouldin score for number of cluster(s) 4: 0.5640338452949106
# V-measure score for number of cluster(s) 4: 0.8124881110670106
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 5: -2.7524874955215775
# Silhouette score for number of cluster(s) 5: 0.576212868689931
# Davies Bouldin score for number of cluster(s) 5: 0.6115969433282199
# V-measure score for number of cluster(s) 5: 0.9854329348806474
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 6: -2.5651715811566866
# Silhouette score for number of cluster(s) 6: 0.5044327660104448
# Davies Bouldin score for number of cluster(s) 6: 0.8822555543422856
# V-measure score for number of cluster(s) 6: 0.9175210786837888
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 7: -2.432992841102872
# Silhouette score for number of cluster(s) 7: 0.4455132752436083
# Davies Bouldin score for number of cluster(s) 7: 1.1624941990032995
# V-measure score for number of cluster(s) 7: 0.8858769125044887
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 8: -2.2663419165304974
# Silhouette score for number of cluster(s) 8: 0.3913750386666644
# Davies Bouldin score for number of cluster(s) 8: 1.248965493492306
# V-measure score for number of cluster(s) 8: 0.8378286142525653
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 9: -2.1542376757566304
# Silhouette score for number of cluster(s) 9: 0.3509024007153109
# Davies Bouldin score for number of cluster(s) 9: 1.361149397026128
# V-measure score for number of cluster(s) 9: 0.8290173378719918
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 10: -2.055031222680875
# Silhouette score for number of cluster(s) 10: 0.3567985956749596
# Davies Bouldin score for number of cluster(s) 10: 1.3076285029868209
# V-measure score for number of cluster(s) 10: 0.8116712652581253
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 11: -1.9944599505628633
# Silhouette score for number of cluster(s) 11: 0.3435870864369116
# Davies Bouldin score for number of cluster(s) 11: 1.3114473676939808
# V-measure score for number of cluster(s) 11: 0.7985185977203607
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The elbow method for determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_scores,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("K-means score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=vmeasure_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("V-measure score")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("The silhouette coefficient method \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_silhouette,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Silhouette score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=db_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Davies-Bouldin score")
plt.show()

# %% [markdown]
# ## Expectation-maximization (Gaussian Mixture Model)

# %%
from sklearn.mixture import GaussianMixture

# %%
gm_bic= []
gm_score=[]
for i in range(2,12):
    gm = GaussianMixture(n_components=i,n_init=10,tol=1e-3,max_iter=1000).fit(X_scaled)
    print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(X_scaled)))
    print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(X_scaled)))
    print("-"*100)
    gm_bic.append(-gm.bic(X_scaled))
    gm_score.append(gm.score(X_scaled))
# Out:
# BIC for number of cluster(s) 2: -1213.4749603954222
# Log-likelihood score for number of cluster(s) 2: 3.417815410063288
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: -1305.9196841330486
# Log-likelihood score for number of cluster(s) 3: 3.847614120652905
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: -1335.8267421567461
# Log-likelihood score for number of cluster(s) 4: 4.121068666957701
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: -1317.0352907232477
# Log-likelihood score for number of cluster(s) 5: 4.272776939619506
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: -1274.873913498081
# Log-likelihood score for number of cluster(s) 6: 4.366060397802141
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: -1214.9120435078034
# Log-likelihood score for number of cluster(s) 7: 4.414842624071998
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: -1173.0911342058284
# Log-likelihood score for number of cluster(s) 8: 4.508977252062612
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: -1126.2652445800763
# Log-likelihood score for number of cluster(s) 9: 4.590599429243783
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: -1083.773510699757
# Log-likelihood score for number of cluster(s) 10: 4.683056995788536
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: -1030.2768973396821
# Log-likelihood score for number of cluster(s) 11: 4.7480023636339
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The Gaussian Mixture model BIC \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=np.log(gm_bic),s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Log of Gaussian mixture BIC score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=gm_score,s=150,edgecolor='k')
plt.show()
